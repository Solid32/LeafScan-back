# %% [markdown]
# <div style="text-align: center;">
#     <span style="font-size: 24px; font-weight: bold;">AppAI Presentation</span>
# </div>

# %% [markdown]
# <div style="text-align: center;">
#     <span style="font-size: 24px; font-weight: bold;">LeafScan Quizz !</span>
# </div>
#
#
#
# ![leafscan.png](attachment:leafscan.png)

# %%
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds
# Out:
# 2023-06-08 15:08:39.425624: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-08 15:08:39.821389: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-06-08 15:08:39.849790: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# ...

# %%
data_dir = '../raw_data'
ds = tf.keras.utils.image_dataset_from_directory(
  data_dir)
# Out:
# Found 55448 files belonging to 39 classes.
# 2023-06-08 15:08:50.236680: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-06-08 15:08:50.236829: W tensorflow/stream_executor/cuda/cuda_driver.cc:263] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-06-08 15:08:50.236920: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (CyberA): /proc/driver/nvidia/version does not exist
# 2023-06-08 15:08:50.238617: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(9, 9))
for images, labels in ds.take(2):
    for i in range(9):
        ax = plt.subplot(3, 3, i + 1)
        plt.imshow(images[i].numpy().astype("uint8"))
        #plt.title(ds.class_names[labels[i]])
        plt.axis("off")

# %% [markdown]
# # If the leaf is recognised and is healthy:

# %% [markdown]
# ![healthy_leaf.png](attachment:healthy_leaf.png)
#
#
# ## This is a < Leaf_species > !
#
# And this leaf looks very healthy! with xx accuracy !
# Keep up the good work!
#
# ## Retry

# %% [markdown]
# # If the leaf is recognised and has a disease:

# %% [markdown]
# ![diseased_leaf-2.png](attachment:diseased_leaf-2.png)
#
#
# ## This is a < Leaf_species >!
#
# Unfortunately your leaf doesn't look very happy...
# We've detected < leaf_disease > with xx accuracy !
#
# To help you out, use this [link]!
#
# [link]: https://simonsinek.com/optimism_press_books/how-to-make-a-plant-love-you/
#
# ## Retry

# %% [markdown]
# # If no leaf is recognised (bad quality or not in picture):

# %% [markdown]
# We're very sorry but we can't recognise this leaf...
#
# please try again !

# %% [markdown]
# # To conclude: Project Status:
#
# the quizz is almost ready for the beginning of next week
#
# If we have time, the plan is to improve the frontend to be able to actually load any image (within our trained species) to be more user-interactive.
